# %%
from bundle import Bundle
from attraction import Attraction
import numpy as np
import pandas as pd

# %%
aq = pd.read_csv('../data/sea_aquarium.csv')
name = "sea aquarium"
cost = 33

sea_aquarium_attraction = Attraction(name, cost, aq)

# %%
cc = pd.read_csv('../data/cablecar.csv')
name = "cable car"
cost = 33

cc_attraction = Attraction(name, cost, cc)

# %%
lst_of_attraction = [sea_aquarium_attraction, cc_attraction]

# %%
b1 = Bundle(list_of_attractions=lst_of_attraction)
b1.get_best_revenue()
# Out:
# Optimization terminated successfully.
#          Current function value: -3172768.777665
#          Iterations: 35
#          Function evaluations: 70
# array([34.0001875])

# %%
b1.get_min_possible_price()
# Out:
# 34.0

# %%
b1.get_price_revenue_graph()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function
def my_function(x):
    return np.sin(x)

# Generate x values
x = np.linspace(-2*np.pi, 2*np.pi, 100)

# Generate y values
y = my_function(x)

# Plot the graph
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Function Graph: y = sin(x)')
plt.grid(True)
plt.show()
